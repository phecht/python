# %%
import requests
r = requests.get("https://wescom.org")
print(r.content)
# Out:
# b'\r\n<!DOCTYPE html>\r\n<html lang=en-us>\r\n<head>\r\n    <meta charset="utf-8">\r\n    <meta http-equiv="x-ua-compatible" content="ie=edge">\r\n\t<title>Wescom Credit Union | HOME</title>\r\n    <meta name="title" content="Wescom Credit Union">\r\n    <meta name=viewport content="width=device-width,initial-scale=1">\r\n    <base href="/">\r\n\t<!-- Basic Page Needs\r\n  ================================================== -->\r\n\t<meta name="description" content="Wescom Credit Union offers residents of Southern California convenient banking through a robust branch network, internet, phone, and thousands of ATMs." >\r\n\t<!--Open Graph Data-->\r\n\t<meta property="og:url" content="https://www.wescom.org/index.asp" />\r\n\t<meta property="og:title" content="Wescom Credit Union | HOME" />\r\n\t<meta property="og:description" content="Wescom Credit Union offers residents of Southern California convenient banking through a robust branch network, internet, phone, and thousands of ATMs." 
# ...

# %%
p=4
r=5
print(r+p)
# Out:
# 9
